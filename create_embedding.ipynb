# %%
import pandas as pd
import numpy as np
import torch
import os

# %%
songs_df = pd.read_csv('data/cleaned_songs.csv')
songs_df
# Out:
#              artist_name                      id  \
# 0          Missy Elliott  0UaMYEvWZi0ZqiDOoHU3YI
# 1         Britney Spears  6I9VzXrHxO9rA9A5euc8Ak
# 2                Beyoncé  0WqIKmW4BTrj3eJFmnCKMv
# 3      Justin Timberlake  1AWQoqb9bSvzTjaLralEkT
# 4                 Shaggy  1lzr43nnXAijIGYnCT8M8H
# ...                  ...                     ...
# 34242              Jon D  3uCHI1gfOUL5j5swEh0TcH
# 34243          Big Words  0P1oO2gREMYUCoOkzYAyFu
# 34244       Allan Rayman  2oM4BuruDnEvk59IvIXCwn
# 34245          Jon Jason  4Ri5TTUgjM96tbQZd5Ua7V
# 34246           Grizfolk  5RVuBrXVLptAEbGJdSDzL5
#
#                                          track_name  danceability  energy  \
# 0        Lose Control (feat. Ciara & Fat Man Scoop)         0.904   0.813
# 1                                             Toxic         0.774   0.838
# 2                                     Crazy In Love         0.664   0.758
# 3                                    Rock Your Body         0.892   0.714
# ...

# %% [markdown]
# linear embeddeings vs non-linear
# text embedding frozen moded
# -  sequentioal relationships
# trtadiditional dataset, frozen, notjhing dynamic
# imaes and text, cnvulution makes sense

# %% [markdown]
# ## Data Preprocessing

# %%
# drop rows with identical artist_name and track_name
songs_df = songs_df.drop_duplicates(subset=['artist_name', 'track_name'], keep='first')
songs_df
# Out:
#              artist_name                      id  \
# 0          Missy Elliott  0UaMYEvWZi0ZqiDOoHU3YI
# 1         Britney Spears  6I9VzXrHxO9rA9A5euc8Ak
# 2                Beyoncé  0WqIKmW4BTrj3eJFmnCKMv
# 3      Justin Timberlake  1AWQoqb9bSvzTjaLralEkT
# 4                 Shaggy  1lzr43nnXAijIGYnCT8M8H
# ...                  ...                     ...
# 34242              Jon D  3uCHI1gfOUL5j5swEh0TcH
# 34243          Big Words  0P1oO2gREMYUCoOkzYAyFu
# 34244       Allan Rayman  2oM4BuruDnEvk59IvIXCwn
# 34245          Jon Jason  4Ri5TTUgjM96tbQZd5Ua7V
# 34246           Grizfolk  5RVuBrXVLptAEbGJdSDzL5
#
#                                          track_name  danceability  energy  \
# 0        Lose Control (feat. Ciara & Fat Man Scoop)         0.904   0.813
# 1                                             Toxic         0.774   0.838
# 2                                     Crazy In Love         0.664   0.758
# 3                                    Rock Your Body         0.892   0.714
# ...

# %%
#drop subjectivity, polarity, genres
songs_df = songs_df.drop(columns=['subjectivity', 'polarity', 'genres'])
#create a new colunm with the first genre in the list in genre_list

# %% [markdown]
# ## Encoding Data with Variational Autoencoder

# %% [markdown]
# Distances are meanigful in appliciation
